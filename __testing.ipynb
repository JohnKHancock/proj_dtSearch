# %%
from nlp_dtsearch import NLPdtSearch

# %%
# Initialize the converter (loads API key from .env file automatically)
# TIP: Create this ONCE and reuse it - don't recreate in every cell!
# If OPENAI_API_KEY is already in environment, set auto_load_env=False for faster init
converter = NLPdtSearch()

# For even faster initialization if env var is already set:
# converter = NLPdtSearch(auto_load_env=False)

# %%
message = """

I am looking for all instances the word 'Amoxicillin' in all documents. The word may be misspelled.
So, we will need to use fuzzy matching, phonetic matching, and different variations of the word in the search.
Can you provide a few different ways to do this search?

"""

# %%
suggestions = converter.convert_to_dtSearch(message)
print(suggestions)
